# %% [markdown]
# ## Computer Vision 1st Assignment
# ## Melika Heydari Rad
# #### Maktabkhooneh Course

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('erik_demaine.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(RGB_img)

# %%
# صرفا جهت امتحان کردن نمایش توسط openCV
cv2.imshow('Erik_in_window',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
face = RGB_img[40:250, 300:500]

plt.figure(figsize=(3,3))
plt.imshow(face)

# %%
RGB_face = face[:,:,::-1]
# یا 
# RGB_face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)

# %%
cv2.imwrite('./Erik_face.jpg', RGB_face)
# Out:
# True
