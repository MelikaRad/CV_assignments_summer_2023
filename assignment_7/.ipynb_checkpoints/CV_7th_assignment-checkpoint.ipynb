# %% [markdown]
# ## Computer Vision 7th Assignment
# ## Melika Heydari Rad
# #### Maktabkhooneh Course

# %% [markdown]
# یک برنامه بنویسید که ویدیوی اصلی وبکم و همچنین تصویر وبکم بعد از اعمال  تصحیح روشنایی و تضاد (به روش اصلاح گاما) را نمایش دهد. این برنامه با فشردن
# q
# روی کیبورد باید بسته شود.

# %% [markdown]
# تصویر وبکم ؟ منظور همون وبکمه دیگه ؟

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
cap = cv2.VideoCapture(0)



gamma = 0.25
lookUpTable = np.empty((1,256), np.uint8)

for i in range(256):
    lookUpTable[0,i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)

while True:
    ret, frame = cap.read()
    
    gamma_corrected_frame = cv2.LUT(frame, lookUpTable)
    
    cv2.imshow('original_webcam', frame)
    cv2.imshow('gamma_corrected_webcam', gamma_corrected_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# Release camera and close windows

cap.release()
cv2.destroyAllWindows()

# %%
# showing the last original frame
plt.imshow(frame)

# %%
# showing the last corrected frame 
plt.imshow(gamma_corrected_frame)
